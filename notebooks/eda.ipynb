# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))

# %%
from pathlib import Path
from src.mslm.utils import create_dataloaders, prepare_datasets
from src.mslm.dataloader import KeypointDataset

# %%
import matplotlib.pyplot as plt

# %%
h5_file = Path("/home/giorgio6846/Code/Sign-AI/data/processed/dataset_v4.hdf5")
train_ratio = 0.8
batch_size = 64
key_points = 133

keypoint_reader = KeypointDataset(h5Path=h5_file, return_label=True, n_keypoints=key_points, data_augmentation=False, max_length=4000)
tr_ds, val_ds, tr_len, val_len = keypoint_reader.split_dataset(train_ratio)
# Out:
# Videos:  4118

# %%
words = [a[2] for a in tr_ds]

# %%
from collections import Counter
word_counts = Counter(words)

# %%
plt.figure(figsize=(50, 10))
# sort by counts and get the 20 uncommon words



plt.xticks(rotation=90)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Word Frequency Distribution')
plt.tight_layout()
plt.show()

# %%
# create a word cloud
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
